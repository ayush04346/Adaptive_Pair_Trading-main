# %% [markdown]
# # Notebook 00 — Pair Selection Framework
#
# **Adaptive Pair Trading using Cointegration, Volatility and ML Diagnostics**
# **Author:** Ayush Arora (MQMS2404)
#
# ---
#
# ## Objective
#
# This notebook implements a **hierarchical pair selection framework** to identify
# economically meaningful and statistically tradable stock pairs.
#
# The goal is **not** to find the most profitable pair, but to systematically filter
# out weak candidates before applying deeper statistical arbitrage analysis.
#
# The selected pairs are then passed to subsequent notebooks for validation,
# modeling, and backtesting.

# %% [markdown]
# ## Cell 1: Import required libraries

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.tsa.stattools import coint, adfuller
import itertools

# %% [markdown]
# ## Cell 2: Load cleaned price data

# %%
prices = pd.read_csv('data/prices.csv', index_col=0, parse_dates=True)
prices = prices.dropna(axis=1)
prices.head()
# Out:
#                  ABB.NS  ADANIENT.NS  ADANIPORTS.NS  AMBUJACEM.NS  \
# Date
# 2015-01-01  1131.143555    70.761368     301.772858    195.773010
# 2015-01-02  1119.410767    71.107956     301.584015    198.523697
# 2015-01-05  1119.671143    72.284912     305.786499    198.265808
# 2015-01-06  1109.502930    71.736145     303.944946    190.959244
# 2015-01-07  1093.510986    71.100731     303.236633    189.197098
#
#             APOLLOHOSP.NS  ASHOKLEY.NS  ASIANPAINT.NS  AUROPHARMA.NS  \
# Date
# 2015-01-01    1084.179443    21.544609     684.931519     532.220825
# 2015-01-02    1086.056763    22.124655     708.611450     534.770630
# 2015-01-05    1089.667969    23.947659     708.565674     534.510925
# 2015-01-06    1057.216675    23.429758     691.651550     513.663208
# 2015-01-07    1065.498047    24.714153     705.548523     521.808777
#
#             AXISBANK.NS  BAJAJ-AUTO.NS  ...       TCS.NS    TECHM.NS  \
# Date                                    ...
# ...

# %% [markdown]
# ## Cell 3: Define economically meaningful universe (example: metals)
#
# Pairs are generated **within sectors** to preserve economic logic.
# This example focuses on the metals sector.

# %%
metal_stocks = [
    'JSWSTEEL.NS', 'TATASTEEL.NS', 'HINDALCO.NS', 'VEDL.NS'
]

pairs = list(itertools.combinations(metal_stocks, 2))
pairs
# Out:
# [('JSWSTEEL.NS', 'TATASTEEL.NS'),
#  ('JSWSTEEL.NS', 'HINDALCO.NS'),
#  ('JSWSTEEL.NS', 'VEDL.NS'),
#  ('TATASTEEL.NS', 'HINDALCO.NS'),
#  ('TATASTEEL.NS', 'VEDL.NS'),
#  ('HINDALCO.NS', 'VEDL.NS')]

# %% [markdown]
# ## Cell 4: Correlation filter
#
# Pairs with insufficient co-movement are removed at this stage.

# %%
def corr_filter(prices, pairs, threshold=0.4):
    records = []
    for a, b in pairs:
        corr = prices[a].pct_change().corr(prices[b].pct_change())
        if corr > threshold:
            records.append((a, b, corr))
    return pd.DataFrame(records, columns=['Stock A', 'Stock B', 'Correlation'])

corr_pairs = corr_filter(prices, pairs)
corr_pairs
# Out:
#         Stock A      Stock B  Correlation
# 0  TATASTEEL.NS  HINDALCO.NS     0.692928
# 1  TATASTEEL.NS      VEDL.NS     0.628697
# 2   HINDALCO.NS      VEDL.NS     0.652886

# %% [markdown]
# ## Cell 5: Cointegration testing
#
# Engle–Granger cointegration test is applied to correlated pairs.

# %%
def cointegration_test(prices, df, alpha=0.05):
    records = []
    for _, row in df.iterrows():
        a, b = row['Stock A'], row['Stock B']
        _, pval, _ = coint(prices[a], prices[b])
        if pval < alpha:
            records.append((a, b, row['Correlation'], pval))
    return pd.DataFrame(records, columns=['Stock A', 'Stock B', 'Correlation', 'Coint p-value'])

coint_pairs = cointegration_test(prices, corr_pairs)
coint_pairs
# Out:
#         Stock A      Stock B  Correlation  Coint p-value
# 0  TATASTEEL.NS  HINDALCO.NS     0.692928       0.000586

# %% [markdown]
# ## Cell 6: Stationarity of the OLS-residual spread
#
# The ADF test must be applied to the **OLS residual** (cointegration residual), not the raw
# price difference. Using raw prices ignores the estimated hedge ratio and will almost always
# reject stationarity even for genuinely cointegrated pairs — this was the root cause of the
# empty output in a naive implementation.
#
# The OLS residual is:  `spread = A − β·B − α`

# %%
def adf_spread_test(prices, df):
    """
    ADF stationarity test on the OLS-residual spread (A - beta*B - alpha).
    Testing the raw price difference is incorrect because it ignores the hedge
    ratio, causing genuinely cointegrated pairs to fail this filter.
    """
    records = []
    for _, row in df.iterrows():
        a, b = row['Stock A'], row['Stock B']
        model = sm.OLS(prices[a], sm.add_constant(prices[b])).fit()
        spread = model.resid                            # proper cointegration residual
        adf_stat, pval, _, _, _, _ = adfuller(spread)
        if pval < 0.05:
            records.append((a, b, row['Correlation'], row['Coint p-value'], round(adf_stat, 4), round(pval, 6)))
    cols = ['Stock A', 'Stock B', 'Correlation', 'Coint p-value', 'ADF stat', 'ADF p-value']
    return pd.DataFrame(records, columns=cols)

stationary_pairs = adf_spread_test(prices, coint_pairs)
stationary_pairs

# %% [markdown]
# ## Cell 7: Half-life of mean reversion
#
# Half-life is estimated from the OLS-residual spread via an AR(1) regression:
#
# ```
# Δspread_t = λ · spread_{t-1} + ε_t
# half-life = −ln(2) / λ
# ```
#
# Only pairs whose spread reverts in 5–90 trading days are practical candidates:
# - Below 5 days: reversion is too fast (bid-ask friction consumes alpha)
# - Above 90 days: capital is locked up too long

# %%
def half_life(spread):
    spread_lag = spread.shift(1).dropna()
    spread_ret = spread.diff().dropna()
    beta = np.polyfit(spread_lag, spread_ret, 1)[0]
    if beta >= 0:
        return np.inf
    return -np.log(2) / beta

def compute_half_life(prices, df, min_hl=5, max_hl=90):
    """
    Compute half-life from the OLS-residual spread.
    Practical range: 5–90 trading days.
    """
    records = []
    for _, row in df.iterrows():
        a, b = row['Stock A'], row['Stock B']
        model = sm.OLS(prices[a], sm.add_constant(prices[b])).fit()
        spread = model.resid
        hl = half_life(spread)
        if min_hl <= hl <= max_hl:
            records.append((a, b, row['Correlation'], row['Coint p-value'],
                            row['ADF stat'], row['ADF p-value'], round(hl, 1)))
    cols = ['Stock A', 'Stock B', 'Correlation', 'Coint p-value', 'ADF stat', 'ADF p-value', 'Half-life (days)']
    return pd.DataFrame(records, columns=cols)

final_pairs = compute_half_life(prices, stationary_pairs)
final_pairs.sort_values('Half-life (days)')

# %% [markdown]
# ## Final Output
#
# The hierarchical filter retains pairs that satisfy **all** of the following:
#
# | Filter | Criterion | Rationale |
# |--------|-----------|-----------|
# | Sector | Same industry | Economic plausibility |
# | Correlation | Returns correlation > 0.40 | Co-movement pre-screen |
# | Cointegration | Engle–Granger p-value < 0.05 | Long-run equilibrium |
# | Spread stationarity | ADF on OLS residual p-value < 0.05 | Mean-reverting behaviour |
# | Half-life | 5–90 trading days | Practical tradability |
#
# **Key fix vs. naive implementation:** ADF is applied to the OLS-residual spread
# (`A − β·B − α`), not the raw price difference. Using raw prices ignores the hedge ratio
# and systematically rejects valid cointegrated pairs.
#
# Selected pair forwarded to NB02–NB07: **TATASTEEL.NS / HINDALCO.NS**
